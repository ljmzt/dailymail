# %%
from bpe_construct import *
from bpe_tokenizer import BPETokenizer
import pickle

# %%
# !wc -l dataset/dailymail/*.txt
# Out:
#   219507 dataset/dailymail/onebigfile.txt
#   219507 dataset/dailymail/onebigfile_lemma.txt
#    10000 dataset/dailymail/onebigfile_mid_lemma.txt
#     1000 dataset/dailymail/onebigfile_test.txt
#     1000 dataset/dailymail/onebigfile_test_lemma.txt
#       20 dataset/dailymail/onetinyfile.txt
#   451034 total

# %%
punctuations = '\'`!,[)>%{="*}@.$(:;|/?&]+#'
space = ' '
filename = 'dataset/dailymail/onebigfile.txt'
first_lines = 10000
vocab_sizes = [10000, 15000, 20000]

# %%
construct(filename, space, punctuations, first_lines=first_lines, vocab_sizes=vocab_sizes)
# Out:
# done reading in sentences
# done init counts
# 1 merging: ->('e', ' ')<- 1267615
# 2 merging: ->('s', ' ')<- 893326
# 3 merging: ->('t', 'h')<- 780517
# 4 merging: ->('d', ' ')<- 740184
# 5 merging: ->('t', ' ')<- 638751
# 6 merging: ->('i', 'n')<- 631585
# 7 merging: ->('e', 'r')<- 542662
# 8 merging: ->('a', 'n')<- 468089
# 9 merging: ->('th', 'e ')<- 397297
# 10 merging: ->('y', ' ')<- 395286
# 11 merging: ->('o', 'n')<- 385013
# 12 merging: ->('.', ' ')<- 353062
# skip
# 13 merging: ->('e', 'n')<- 336330
# 14 merging: ->('o', ' ')<- 319222
# 15 merging: ->('e', 'd ')<- 308792
# 16 merging: ->(',', ' ')<- 302691
# skip
# 17 merging: ->('a', 'r')<- 301672
# 18 merging: ->('o', 'r')<- 295710
# 19 merging: ->('g', ' ')<- 256747
# 20 merging: ->('er', ' ')<- 256691
# 21 merging: ->('a', ' ')<- 247079
# 22 merging: ->('a', 'l')<- 240428
# 23 merging: ->('o', 'u')<- 231474
# 24 merging: ->('in', 'g ')<- 228063
# 25 merging: ->('r', 'e')<- 214909
# 26 merging: ->(' ', 'the ')<- 209437
# ...
